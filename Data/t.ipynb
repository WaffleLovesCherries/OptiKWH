# %%
import pandas as pd
df = pd.read_csv( 'cities.csv' )

# %%
df
# Out:
#                         city      lat       lng
# 0                 Tokyo, JPN  35.6897  139.6922
# 1               Jakarta, IDN  -6.1750  106.8275
# 2                 Delhi, IND  28.6100   77.2300
# 3             Guangzhou, CHN  23.1300  113.2600
# 4                Mumbai, IND  19.0761   72.8775
# ...                      ...      ...       ...
# 47863        Munha-dong, PRK  39.3813  127.2517
# 47864            Sil-li, PRK  39.4880  125.4640
# 47865              Muan, KOR  34.9897  126.4714
# 47866         Hongseong, KOR  36.6009  126.6650
# 47867  Charlotte Amalie, VIR  18.3420  -64.9331
#
# [47868 rows x 3 columns]

# %%
test = [ 'Guangzhou, CHN', 'Sil-li, PRK', 'City 1', 'Muan, KOR', 'City 2', 'Muan, KOR' ]

rows = [dict(df[df['city'] == city].iloc[0]) if city in df['city'].values else {'city': city, 'lat': 0.0, 'lng': 0.0} for city in test]

# %%
list(df['city'])
# Out:
# ['Tokyo, JPN',
#  'Jakarta, IDN',
#  'Delhi, IND',
#  'Guangzhou, CHN',
#  'Mumbai, IND',
#  'Manila, PHL',
#  'Shanghai, CHN',
#  'São Paulo, BRA',
#  'Seoul, KOR',
#  'Mexico City, MEX',
#  'Cairo, EGY',
#  'New York, USA',
#  'Dhaka, BGD',
#  'Beijing, CHN',
#  'Kolkāta, IND',
#  'Bangkok, THA',
#  'Shenzhen, CHN',
#  'Moscow, RUS',
#  'Buenos Aires, ARG',
#  'Lagos, NGA',
#  'Istanbul, TUR',
#  'Karachi, PAK',
#  'Bangalore, IND',
#  'Ho Chi Minh City, VNM',
#  'Ōsaka, JPN',
#  'Chengdu, CHN',
#  'Tehran, IRN',
#  'Kinshasa, COD',
#  'Rio de Janeiro, BRA',
#  'Chennai, IND',
#  'Xi’an, CHN',
#  'Lahore, PAK',
#  'Chongqing, CHN',
#  'Los Angeles, USA',
#  'Baoding, CHN',
#  'London, GBR',
#  'Paris, FRA',
#  'Linyi, CHN',
#  'Dongguan, CHN',
#  'Hyderābād, IND',
#  'Tianjin, CHN',
#  'Lima, PER',
#  'Wuhan, CHN',
#  'Nanyang, CHN',
#  'Hangzhou, CHN',
#  'Foshan, CHN',
#  'Nagoya, JPN',
#  'Tongshan, CHN',
#  'Luanda, AGO',
#  'Zhoukou, CHN',
#  'Ganzhou, CHN',
# ...

# %%
rows
# Out:
# [{'city': 'Guangzhou, CHN', 'lat': 23.13, 'lng': 113.26},
#  {'city': 'Sil-li, PRK', 'lat': 39.488, 'lng': 125.464},
#  {'city': 'City 1', 'lat': 0.0, 'lng': 0.0},
#  {'city': 'Muan, KOR', 'lat': 34.9897, 'lng': 126.4714},
#  {'city': 'City 2', 'lat': 0.0, 'lng': 0.0},
#  {'city': 'Muan, KOR', 'lat': 34.9897, 'lng': 126.4714}]
